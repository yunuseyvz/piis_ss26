# %% [markdown]
# # Example 3 — Messy on purpose
#
# This notebook has out-of-order execution, an unused variable, and a duplicated cell. Press **Initialize FlowQuest** and watch the missions populate. Each fix nudges Notebook Health closer to 100.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load

# %%
df = pd.DataFrame({'x': [1, 2, 3, 4, 5], 'y': [10, 20, 30, 40, 50]})
df

# %% [markdown]
# ## Clean (twice, oops)

# %%
df = df.dropna()

# %%
df = df.dropna()

# %% [markdown]
# ## Define an unused helper

# %%
leftovers = df['x'].cumsum()  # never referenced again

# %% [markdown]
# ## Inspect

# %%
df.describe()
