# %% [markdown]
# # Messy on purpose
#
# This notebook has **out-of-order execution**, an **unused variable**, and a **duplicated cell**. Re-scan it from the FlowQuest banner and watch the *stabilization* missions populate — claiming each fix pours XP into your global total.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load

# %% [markdown]
# ## Clean (twice, oops)

# %%
df = df.dropna()

# %% [markdown]
# ## Define an unused helper

# %%
rain_cumsum = df['rain_mm'].cumsum()  # computed but never used again

# %% [markdown]
# ## Inspect

# %%
df.sort_values('temp', ascending=False)

# %% [markdown]
# ## Your move
#
# Fix the smells (drop the duplicate, remove or use the leftover variable, re-run top-to-bottom) and claim the missions as they auto-clear.

# %%
df = pd.DataFrame({
    'city': ['Berlin', 'Paris', 'Rome', 'Madrid', 'Vienna'],
    'temp': [12.5, 14.0, 18.2, 19.1, 11.3],
    'rain_mm': [58, 49, 38, 28, 66],
})
df
df = pd.DataFrame({
    'city': ['Berlin', 'Paris', 'Rome', 'Madrid', 'Vienna'],
    'temp': [12.5, 14.0, 18.2, 19.1, 11.3],
    'rain_mm': [58, 49, 38, 28, 66],
})
df
